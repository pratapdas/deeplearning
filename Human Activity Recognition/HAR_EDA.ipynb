# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is focussed to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# The dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone attached to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# Here, 'jerk' is rate of change of acceleration.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Data Size :
# > 269 MB

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) train and 30%(7) test data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtaining the  train data

# %%
# getting the data from txt files to pandas datafame
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None)
X_train.columns = features

# adding subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# putting all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 7082           0.247348          -0.036688          -0.091821
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 7082         -0.477771         -0.262008         -0.193545         -0.538394
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 7082         -0.272726         -0.204295         -0.113911  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 7082                     0.255351                              -0.60849
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 7082                          0.952984                             -0.950583
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 7082             -0.856326               0.19292              0.048918
#
#       subject  Activity  ActivityName
# 7082       30         1       WALKING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtaining the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns = features

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1979           0.387323          -0.027285          -0.129375
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1979          -0.32086          -0.30502         -0.388126         -0.381561
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 1979         -0.318524         -0.348491           0.07373  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 1979                    -0.748988                             -0.096695
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 1979                          0.745735                              -0.07009
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 1979             -0.794269              0.222016             -0.054468
#
#       subject  Activity        ActivityName
# 1979       18         3  WALKING_DOWNSTAIRS
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Checking for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Checking for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# **Observation:** We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Observation:** Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Saving train and test dataframes in csv files

# %%
train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)

# %%
#This is done to avoid the duplicate column names
train  = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Feature Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', height=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate the classes well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **__Observations__:**
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% of the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of Gravity Acceleration Components also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# **__Observations__:**
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# # Applying t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.740s...
# [t-SNE] Computed neighbors for 7352 samples in 37.424s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.035s
# [t-SNE] Iteration 50: error = 124.7601700, gradient norm = 0.0258340 (50 iterations in 1.997s)
# [t-SNE] Iteration 100: error = 106.8396530, gradient norm = 0.0298704 (50 iterations in 1.599s)
# [t-SNE] Iteration 150: error = 100.5894470, gradient norm = 0.0235455 (50 iterations in 1.353s)
# [t-SNE] Iteration 200: error = 97.2511978, gradient norm = 0.0174356 (50 iterations in 1.341s)
# [t-SNE] Iteration 250: error = 94.9800110, gradient norm = 0.0156432 (50 iterations in 1.449s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 94.980011
# [t-SNE] Iteration 300: error = 4.1113448, gradient norm = 0.0015577 (50 iterations in 1.325s)
# [t-SNE] Iteration 350: error = 3.2050960, gradient norm = 0.0010023 (50 iterations in 1.277s)
# [t-SNE] Iteration 400: error = 2.7770486, gradient norm = 0.0007237 (50 iterations in 1.331s)
# [t-SNE] Iteration 450: error = 2.5134063, gradient norm = 0.0005645 (50 iterations in 1.381s)
# [t-SNE] Iteration 500: error = 2.3301640, gradient norm = 0.0004779 (50 iterations in 1.314s)
# [t-SNE] Iteration 550: error = 2.1920886, gradient norm = 0.0004178 (50 iterations in 1.328s)
# [t-SNE] Iteration 600: error = 2.0827954, gradient norm = 0.0003667 (50 iterations in 1.321s)
# [t-SNE] Iteration 650: error = 1.9931337, gradient norm = 0.0003310 (50 iterations in 1.401s)
# [t-SNE] Iteration 700: error = 1.9176989, gradient norm = 0.0003024 (50 iterations in 1.353s)
# [t-SNE] Iteration 750: error = 1.8530370, gradient norm = 0.0002767 (50 iterations in 1.347s)
# [t-SNE] Iteration 800: error = 1.7962636, gradient norm = 0.0002586 (50 iterations in 1.364s)
# [t-SNE] Iteration 850: error = 1.7462436, gradient norm = 0.0002435 (50 iterations in 1.385s)
# [t-SNE] Iteration 900: error = 1.7018130, gradient norm = 0.0002248 (50 iterations in 1.346s)
# [t-SNE] Iteration 950: error = 1.6618538, gradient norm = 0.0002116 (50 iterations in 1.378s)
# [t-SNE] Iteration 1000: error = 1.6256112, gradient norm = 0.0002008 (50 iterations in 1.403s)
# [t-SNE] KL divergence after 1000 iterations: 1.625611
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.814s...
# [t-SNE] Computed neighbors for 7352 samples in 31.516s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.041s
# [t-SNE] Iteration 50: error = 113.9677734, gradient norm = 0.0224516 (50 iterations in 1.791s)
# [t-SNE] Iteration 100: error = 97.2300034, gradient norm = 0.0148537 (50 iterations in 1.422s)
# [t-SNE] Iteration 150: error = 92.9868011, gradient norm = 0.0081741 (50 iterations in 1.348s)
# [t-SNE] Iteration 200: error = 91.0554886, gradient norm = 0.0071748 (50 iterations in 1.399s)
# [t-SNE] Iteration 250: error = 89.9083710, gradient norm = 0.0057293 (50 iterations in 1.501s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.908371
# [t-SNE] Iteration 300: error = 3.5694399, gradient norm = 0.0014657 (50 iterations in 1.397s)
# [t-SNE] Iteration 350: error = 2.8099880, gradient norm = 0.0007530 (50 iterations in 1.488s)
# [t-SNE] Iteration 400: error = 2.4303479, gradient norm = 0.0005234 (50 iterations in 1.479s)
# [t-SNE] Iteration 450: error = 2.2134814, gradient norm = 0.0004048 (50 iterations in 1.342s)
# [t-SNE] Iteration 500: error = 2.0689595, gradient norm = 0.0003302 (50 iterations in 1.353s)
# [t-SNE] Iteration 550: error = 1.9640381, gradient norm = 0.0002860 (50 iterations in 1.479s)
# [t-SNE] Iteration 600: error = 1.8832878, gradient norm = 0.0002460 (50 iterations in 1.610s)
# [t-SNE] Iteration 650: error = 1.8183095, gradient norm = 0.0002182 (50 iterations in 1.617s)
# [t-SNE] Iteration 700: error = 1.7645613, gradient norm = 0.0001975 (50 iterations in 1.621s)
# [t-SNE] Iteration 750: error = 1.7192264, gradient norm = 0.0001806 (50 iterations in 1.594s)
# [t-SNE] Iteration 800: error = 1.6802205, gradient norm = 0.0001661 (50 iterations in 1.512s)
# [t-SNE] Iteration 850: error = 1.6463265, gradient norm = 0.0001536 (50 iterations in 1.600s)
# [t-SNE] Iteration 900: error = 1.6164846, gradient norm = 0.0001439 (50 iterations in 1.531s)
# [t-SNE] Iteration 950: error = 1.5900310, gradient norm = 0.0001355 (50 iterations in 1.468s)
# [t-SNE] Iteration 1000: error = 1.5660979, gradient norm = 0.0001259 (50 iterations in 1.332s)
# [t-SNE] KL divergence after 1000 iterations: 1.566098
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.834s...
# [t-SNE] Computed neighbors for 7352 samples in 32.390s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.096s
# [t-SNE] Iteration 50: error = 105.8287888, gradient norm = 0.0180755 (50 iterations in 2.233s)
# [t-SNE] Iteration 100: error = 90.4565582, gradient norm = 0.0117908 (50 iterations in 2.218s)
# [t-SNE] Iteration 150: error = 87.3795013, gradient norm = 0.0061337 (50 iterations in 1.701s)
# [t-SNE] Iteration 200: error = 86.1412354, gradient norm = 0.0039851 (50 iterations in 1.579s)
# [t-SNE] Iteration 250: error = 85.4602585, gradient norm = 0.0034944 (50 iterations in 1.680s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.460258
# [t-SNE] Iteration 300: error = 3.1421547, gradient norm = 0.0013901 (50 iterations in 1.775s)
# [t-SNE] Iteration 350: error = 2.5001335, gradient norm = 0.0006551 (50 iterations in 1.865s)
# [t-SNE] Iteration 400: error = 2.1800342, gradient norm = 0.0004281 (50 iterations in 1.884s)
# [t-SNE] Iteration 450: error = 1.9949245, gradient norm = 0.0003202 (50 iterations in 1.734s)
# [t-SNE] Iteration 500: error = 1.8768269, gradient norm = 0.0002542 (50 iterations in 1.763s)
# [t-SNE] Iteration 550: error = 1.7933694, gradient norm = 0.0002127 (50 iterations in 1.685s)
# [t-SNE] Iteration 600: error = 1.7302686, gradient norm = 0.0001830 (50 iterations in 1.650s)
# [t-SNE] Iteration 650: error = 1.6811423, gradient norm = 0.0001625 (50 iterations in 1.639s)
# [t-SNE] Iteration 700: error = 1.6413795, gradient norm = 0.0001451 (50 iterations in 1.992s)
# [t-SNE] Iteration 750: error = 1.6084156, gradient norm = 0.0001308 (50 iterations in 1.887s)
# [t-SNE] Iteration 800: error = 1.5806173, gradient norm = 0.0001205 (50 iterations in 1.894s)
# [t-SNE] Iteration 850: error = 1.5572345, gradient norm = 0.0001104 (50 iterations in 1.900s)
# [t-SNE] Iteration 900: error = 1.5372175, gradient norm = 0.0001043 (50 iterations in 1.848s)
# [t-SNE] Iteration 950: error = 1.5200682, gradient norm = 0.0000976 (50 iterations in 1.954s)
# [t-SNE] Iteration 1000: error = 1.5051355, gradient norm = 0.0000915 (50 iterations in 1.921s)
# [t-SNE] KL divergence after 1000 iterations: 1.505136
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.868s...
# [t-SNE] Computed neighbors for 7352 samples in 33.696s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.230s
# [t-SNE] Iteration 50: error = 97.3052216, gradient norm = 0.0231511 (50 iterations in 2.030s)
# [t-SNE] Iteration 100: error = 84.0283432, gradient norm = 0.0081395 (50 iterations in 1.831s)
# [t-SNE] Iteration 150: error = 81.9732056, gradient norm = 0.0034267 (50 iterations in 1.794s)
# [t-SNE] Iteration 200: error = 81.2477112, gradient norm = 0.0022743 (50 iterations in 1.711s)
# [t-SNE] Iteration 250: error = 80.8616104, gradient norm = 0.0018034 (50 iterations in 1.746s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.861610
# [t-SNE] Iteration 300: error = 2.7001257, gradient norm = 0.0013095 (50 iterations in 1.751s)
# [t-SNE] Iteration 350: error = 2.1652377, gradient norm = 0.0005732 (50 iterations in 1.871s)
# [t-SNE] Iteration 400: error = 1.9162512, gradient norm = 0.0003477 (50 iterations in 1.797s)
# [t-SNE] Iteration 450: error = 1.7703947, gradient norm = 0.0002473 (50 iterations in 1.752s)
# [t-SNE] Iteration 500: error = 1.6759458, gradient norm = 0.0001968 (50 iterations in 1.735s)
# [t-SNE] Iteration 550: error = 1.6116062, gradient norm = 0.0001591 (50 iterations in 1.774s)
# [t-SNE] Iteration 600: error = 1.5649363, gradient norm = 0.0001351 (50 iterations in 1.750s)
# [t-SNE] Iteration 650: error = 1.5300456, gradient norm = 0.0001189 (50 iterations in 1.760s)
# [t-SNE] Iteration 700: error = 1.5032556, gradient norm = 0.0001079 (50 iterations in 1.842s)
# [t-SNE] Iteration 750: error = 1.4824260, gradient norm = 0.0001009 (50 iterations in 2.009s)
# [t-SNE] Iteration 800: error = 1.4660642, gradient norm = 0.0000952 (50 iterations in 1.888s)
# [t-SNE] Iteration 850: error = 1.4528558, gradient norm = 0.0000886 (50 iterations in 1.883s)
# [t-SNE] Iteration 900: error = 1.4418325, gradient norm = 0.0000808 (50 iterations in 2.052s)
# [t-SNE] Iteration 950: error = 1.4318479, gradient norm = 0.0000760 (50 iterations in 1.940s)
# [t-SNE] Iteration 1000: error = 1.4227812, gradient norm = 0.0000713 (50 iterations in 1.772s)
# [t-SNE] KL divergence after 1000 iterations: 1.422781
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.796s...
# [t-SNE] Computed neighbors for 7352 samples in 34.636s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.450s
# [t-SNE] Iteration 50: error = 86.3456497, gradient norm = 0.0222915 (50 iterations in 2.751s)
# [t-SNE] Iteration 100: error = 75.5266571, gradient norm = 0.0041136 (50 iterations in 2.744s)
# [t-SNE] Iteration 150: error = 74.6782532, gradient norm = 0.0020675 (50 iterations in 2.531s)
# [t-SNE] Iteration 200: error = 74.3066940, gradient norm = 0.0019532 (50 iterations in 2.618s)
# [t-SNE] Iteration 250: error = 74.1253738, gradient norm = 0.0012778 (50 iterations in 2.471s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.125374
# [t-SNE] Iteration 300: error = 2.1503212, gradient norm = 0.0011889 (50 iterations in 2.395s)
# [t-SNE] Iteration 350: error = 1.7529879, gradient norm = 0.0004812 (50 iterations in 2.443s)
# [t-SNE] Iteration 400: error = 1.5847863, gradient norm = 0.0002783 (50 iterations in 2.379s)
# [t-SNE] Iteration 450: error = 1.4910843, gradient norm = 0.0001887 (50 iterations in 2.414s)
# [t-SNE] Iteration 500: error = 1.4314543, gradient norm = 0.0001396 (50 iterations in 2.399s)
# [t-SNE] Iteration 550: error = 1.3906965, gradient norm = 0.0001125 (50 iterations in 2.460s)
# [t-SNE] Iteration 600: error = 1.3619572, gradient norm = 0.0000942 (50 iterations in 2.477s)
# [t-SNE] Iteration 650: error = 1.3409133, gradient norm = 0.0000828 (50 iterations in 2.466s)
# [t-SNE] Iteration 700: error = 1.3252814, gradient norm = 0.0000742 (50 iterations in 2.413s)
# [t-SNE] Iteration 750: error = 1.3132164, gradient norm = 0.0000676 (50 iterations in 2.448s)
# [t-SNE] Iteration 800: error = 1.3038442, gradient norm = 0.0000635 (50 iterations in 2.466s)
# [t-SNE] Iteration 850: error = 1.2968531, gradient norm = 0.0000614 (50 iterations in 2.412s)
# [t-SNE] Iteration 900: error = 1.2913467, gradient norm = 0.0000595 (50 iterations in 2.441s)
# [t-SNE] Iteration 950: error = 1.2868903, gradient norm = 0.0000554 (50 iterations in 2.472s)
# [t-SNE] Iteration 1000: error = 1.2829243, gradient norm = 0.0000537 (50 iterations in 2.430s)
# [t-SNE] KL divergence after 1000 iterations: 1.282924
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# **Observations:**
# - All the classes are well seperable except Standing and Sitting.
# - We might face some challenges in seperating Standing and Sitting, as they are overlapping.
